# %% [markdown]
# # Exploratory Data Analysis (EDA)
# This notebook explores the **Customer Combined Dataset** to understand its structure, quality,
# and underlying patterns. We will generate descriptive statistics, visualize trends, and summarize findings.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Set plot style
sns.set(style='whitegrid')

# %%
filename = "customer_combined_clean.csv"

if os.path.exists(filename):
    df = pd.read_csv(filename)
    print(f"✅ File '{filename}' loaded successfully!")
    display(df.head())  # preview first 5 rows
else:
    print(f"❌ File '{filename}' not found in {os.getcwd()}")
# Out:
# ✅ File 'customer_combined_clean.csv' loaded successfully!
#                              CustomerID  Age  Gender         Location  \
# 0  0009fdd2-ae63-45ca-8d5b-d0ea98381f7b   21  Female      Lake George
# 1  0009fdd2-ae63-45ca-8d5b-d0ea98381f7b   21  Female      Lake George
# 2  000c6bbd-533a-432d-922c-ab64197e71c5   25    Male  North Oliviaton
# 3  000c6bbd-533a-432d-922c-ab64197e71c5   25    Male  North Oliviaton
# 4  000c6bbd-533a-432d-922c-ab64197e71c5   25    Male  North Oliviaton
#
#   IncomeLevel  SignupDate                         TransactionID  \
# 0         Low  2020-11-09  86cd577d-4ffd-498d-94ce-e68e6cca8865
# 1         Low  2020-11-09  86cd577d-4ffd-498d-94ce-e68e6cca8865
# 2        High  2019-11-06  0dc30dbb-8109-4fa8-a7e0-f7ae108075e7
# 3        High  2019-11-06  0dc30dbb-8109-4fa8-a7e0-f7ae108075e7
# 4        High  2019-11-06  0dc30dbb-8109-4fa8-a7e0-f7ae108075e7
#
#   TransactionDate  Amount ProductCategory  PaymentMethod  \
# 0      2023-10-26  389.69   Home & Garden  Bank Transfer
# 1      2023-10-26  389.69   Home & Garden  Bank Transfer
# 2      2023-05-17  500.82     Electronics     Debit Card
# 3      2023-05-17  500.82     Electronics     Debit Card
# 4      2023-05-17  500.82     Electronics     Debit Card
#
#                           InteractionID InteractionDate   Platform  \
# 0  26af70c2-acba-461c-95b8-8200de6b154a      2024-02-16  Instagram
# 1  4d9427f2-30fe-4298-ab66-8490e29202b5      2024-04-22   Facebook
# 2  fff3e62c-3c78-4883-9a34-1d8aad5c1582      2023-07-11  Instagram
# 3  1b2e64c0-80f5-40ed-8d19-072eeb7f2b23      2024-03-15  Instagram
# 4  72c0bb82-9307-4ba4-8925-a5100d3d0e56      2024-03-12    Twitter
#
#   InteractionType Sentiment
# 0           Share  Positive
# 1           Share   Neutral
# 2            Like  Negative
# 3         Comment  Positive
# 4            Like   Neutral

# %%
# Shape of dataset
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

# Column names
print("\nColumns:", df.columns.tolist())

# Info on data types & missing values
df.info()
# Out:
# Rows: 5729
# Columns: 16
#
# Columns: ['CustomerID', 'Age', 'Gender', 'Location', 'IncomeLevel', 'SignupDate', 'TransactionID', 'TransactionDate', 'Amount', 'ProductCategory', 'PaymentMethod', 'InteractionID', 'InteractionDate', 'Platform', 'InteractionType', 'Sentiment']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5729 entries, 0 to 5728
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerID       5729 non-null   object
#  1   Age              5729 non-null   int64
#  2   Gender           5729 non-null   object
#  3   Location         5729 non-null   object
#  4   IncomeLevel      5729 non-null   object
#  5   SignupDate       5517 non-null   object
#  6   TransactionID    5729 non-null   object
#  7   TransactionDate  5593 non-null   object
#  8   Amount           5729 non-null   float64
#  9   ProductCategory  5729 non-null   object
#  10  PaymentMethod    5729 non-null   object
#  11  InteractionID    5729 non-null   object
#  12  InteractionDate  5586 non-null   object
#  13  Platform         5729 non-null   object
#  14  InteractionType  5729 non-null   object
#  15  Sentiment        5729 non-null   object
# dtypes: float64(1), int64(1), object(14)
# memory usage: 716.3+ KB

# %%
# Numeric and categorical stats
df.describe(include='all').transpose()
# Out:
#                   count unique                                   top  freq  \
# CustomerID         5729   3000  7eb7f7df-9b0a-416a-829e-bcf4d8bd57dc    18
# Age              5729.0    NaN                                   NaN   NaN
# Gender             5729      2                                Female  2909
# Location           5729   2696                            West David    20
# IncomeLevel        5729      3                                  High  2333
# SignupDate         5517   1447                            2024-06-08    32
# TransactionID      5729   3000  0dc30dbb-8109-4fa8-a7e0-f7ae108075e7  1576
# TransactionDate    5593    716                            2023-05-17  1587
# Amount           5729.0    NaN                                   NaN   NaN
# ProductCategory    5729      5                           Electronics  2738
# PaymentMethod      5729      4                            Debit Card  2643
# InteractionID      5729   3000  0c3ed7aa-7938-4363-b278-88ceccf756ca  1555
# InteractionDate    5586    366                            2024-04-30  1576
# Platform           5729      3                               Twitter  3197
# InteractionType    5729      3                                 Share  2959
# Sentiment          5729      5                              Positive  3245
#
#                        mean         std  min     25%     50%     75%     max
# CustomerID              NaN         NaN  NaN     NaN     NaN     NaN     NaN
# Age               44.892651   16.191574  0.0    33.0    45.0    57.0   100.0
# Gender                  NaN         NaN  NaN     NaN     NaN     NaN     NaN
# Location                NaN         NaN  NaN     NaN     NaN     NaN     NaN
# IncomeLevel             NaN         NaN  NaN     NaN     NaN     NaN     NaN
# SignupDate              NaN         NaN  NaN     NaN     NaN     NaN     NaN
# TransactionID           NaN         NaN  NaN     NaN     NaN     NaN     NaN
# TransactionDate         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# Amount           496.106528  240.377345  0.0  377.08  500.82  612.51  999.86
# ProductCategory         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# PaymentMethod           NaN         NaN  NaN     NaN     NaN     NaN     NaN
# InteractionID           NaN         NaN  NaN     NaN     NaN     NaN     NaN
# InteractionDate         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# Platform                NaN         NaN  NaN     NaN     NaN     NaN     NaN
# InteractionType         NaN         NaN  NaN     NaN     NaN     NaN     NaN
# Sentiment               NaN         NaN  NaN     NaN     NaN     NaN     NaN

# %%
print("Missing values per column:")
print(df.isnull().sum())
# Out:
# Missing values per column:
# CustomerID           0
# Age                  0
# Gender               0
# Location             0
# IncomeLevel          0
# SignupDate         212
# TransactionID        0
# TransactionDate    136
# Amount               0
# ProductCategory      0
# PaymentMethod        0
# InteractionID        0
# InteractionDate    143
# Platform             0
# InteractionType      0
# Sentiment            0
# dtype: int64
